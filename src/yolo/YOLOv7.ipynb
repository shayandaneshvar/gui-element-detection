# %%
import sys
sys.path.insert(1, 'E:/Research/course research projects/data-driven software engineering/gui-element-detection/src')

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# !conda activate Yolov7_u
import numpy
import torch
print(numpy.__version__)
print(torch.__version__)
print(sys.version)
# !nvidia-smi -L
# Out:
# 1.23.5
# 1.11.0+cu113
# 3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]
# GPU 0: NVIDIA GeForce RTX 3070 Ti Laptop GPU (UUID: GPU-dbf4ddbd-64b1-9aec-ecde-9c9b8ebb3642)

# %%
# %cd yolov7
# Out:
# E:\Research\course research projects\data-driven software engineering\gui-element-detection\src\yolo\yolov7

# %%
TRAIN = False
EPOCHS = 300
import glob

# %%
# !conda activate Yolov7_u
# this does not work - add the created env path to OS environmental variables -> the next line should match with the env's selected python version

# %%
# !python -c "import sys; print(sys.version)"
# Out:
# 3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]

# %%
def set_res_dir():
    # Directory to store results
    res_dir_count = len(glob.glob('runs/train/*'))
    print(f"Current number of result directories: {res_dir_count}")
    if TRAIN:
        RES_DIR = f"results_{EPOCHS}_{res_dir_count+1}"
        print(RES_DIR)
    else:
        RES_DIR = f"results_{EPOCHS}_{res_dir_count}"
    return RES_DIR

def train(res_dir,img_size=416,epochs=EPOCHS):
    # !python train.py --workers 8 --device 0 --batch-size 16 --data data/custom.yaml --img-size {img_size} {img_size} --cfg cfg/training/yolov7_custom.yaml --weights yolov7.pt --name {res_dir} --hyp data/hyp.scratch.p5.yaml --epochs {epochs}
    # !python train.py --workers 8 --device 0 --batch-size 16 --data data/custom.yaml --img-size {img_size} {img_size} --cfg cfg/training/yolov7_custom.yaml --weights yolov7_training.pt --name {res_dir} --hyp data/hyp.scratch.p5.yaml --epochs {epochs}

# %%
RES_DIR = set_res_dir()
# Out:
# Current number of result directories: 22
# results_100_23

# %%
# !wandb disabled
# Out:
# W&B disabled.

# %%
# import torch
# print(torch.__version__)
# print(torch.cuda.is_available())
# print(torch.cuda.current_device())
# Out:
# 1.11.0+cu113
# True
# 0

# %%
train(res_dir=RES_DIR,img_size=416,epochs=100)
# Out:
# ^C

# %%
epochs = 100
img_size = 416
res_dir = RES_DIR

# %%
# !python train.py --workers 8 --device 0 --batch-size 16 --data data/custom.yaml --img-size {img_size} {img_size} --cfg cfg/training/yolov7_custom.yaml --weights yolov7.pt --name {res_dir} --hyp data/hyp.scratch.p5.yaml --epochs {epochs}
# Out:
# ^C

# %%
print("Training Ended")
# Out:
# Training Ended

# %%
# !python test.py --task test --batch-size 16 --data data/custom.yaml --img-size 416 --weights runs/train/conda_custom_env_1007/weights/best.pt --name 'test_results'
# Out:
# Namespace(weights=['runs/train/conda_custom_env_1007/weights/best.pt'], data='data/custom.yaml', batch_size=16, img_size=416, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name="'test_results'", exist_ok=False, no_trace=False, v5_metric=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#                  all         455        6190       0.948        0.89       0.935       0.873
#      BackgroundImage         455          62       0.842       0.887       0.929       0.908
#      CheckedTextView         455          71       0.901       0.648       0.741       0.646
#                 Icon         455        1111       0.954        0.88       0.965       0.829
#             EditText         455         219       0.975       0.959       0.989       0.938
#                Image         455         763       0.905       0.844       0.943       0.885
#                 Text         455        2892       0.967       0.947       0.967       0.877
#           TextButton         455         459       0.974       0.963       0.983       0.976
#               Drawer         455          19       0.984           1       0.996       0.996
#        PageIndicator         455         154       0.997       0.961       0.994       0.794
#         UpperTaskBar         455         370       0.996       0.617       0.734       0.682
#                Modal         455          31       0.938       0.972       0.986       0.978
#               Switch         455          39       0.941           1       0.996       0.967
# Speed: 6.4/1.7/8.0 ms inference/NMS/total per 416x416 image at batch-size 16
# Results saved to runs\test\'test_results'
# YOLOR  2023-3-22 torch 1.11.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8191.5MB)
#
# C:\Users\Shayan\.conda\envs\Yolov7_u\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36541106 parameters, 6194944 gradients, 103.3 GFLOPS
#
# Scanning images:   0%|          | 0/455 [00:00<?, ?it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test' images and labels... 16 found, 0 missing, 0 empty, 0 corrupted:   4%|3         | 16/455 [00:00<00:02, 152.36it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test' images and labels... 33 found, 0 missing, 0 empty, 0 corrupted:   7%|7         | 33/455 [00:00<00:02, 161.61it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test' images and labels... 50 found, 0 missing, 0 empty, 0 corrupted:  11%|#         | 50/455 [00:00<00:02, 163.89it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test' images and labels... 115 found, 0 missing, 0 empty, 0 corrupted:  25%|##5       | 115/455 [00:00<00:00, 351.65it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test' images and labels... 190 found, 0 missing, 0 empty, 0 corrupted:  42%|####1     | 190/455 [00:00<00:00, 492.78it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test' images and labels... 258 found, 0 missing, 0 empty, 0 corrupted:  57%|#####6    | 258/455 [00:00<00:00, 555.01it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test' images and labels... 322 found, 0 missing, 0 empty, 0 corrupted:  71%|#######   | 322/455 [00:00<00:00, 580.72it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test' images and labels... 395 found, 0 missing, 0 empty, 0 corrupted:  87%|########6 | 395/455 [00:00<00:00, 626.79it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test' images and labels... 455 found, 0 missing, 0 empty, 0 corrupted: 100%|##########| 455/455 [00:00<00:00, 505.30it/s]
# test: New cache created: E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test.cache
#
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   0%|          | 0/29 [00:00<?, ?it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   3%|3         | 1/29 [00:01<00:41,  1.46s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   7%|6         | 2/29 [00:01<00:23,  1.16it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  10%|#         | 3/29 [00:02<00:17,  1.49it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  14%|#3        | 4/29 [00:02<00:13,  1.79it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  17%|#7        | 5/29 [00:03<00:11,  2.06it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  21%|##        | 6/29 [00:03<00:10,  2.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  24%|##4       | 7/29 [00:03<00:09,  2.40it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  28%|##7       | 8/29 [00:04<00:08,  2.43it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  31%|###1      | 9/29 [00:04<00:07,  2.50it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  34%|###4      | 10/29 [00:04<00:07,  2.54it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  38%|###7      | 11/29 [00:05<00:06,  2.60it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  41%|####1     | 12/29 [00:05<00:06,  2.64it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  45%|####4     | 13/29 [00:06<00:05,  2.77it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  48%|####8     | 14/29 [00:06<00:05,  2.69it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  52%|#####1    | 15/29 [00:06<00:05,  2.58it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  55%|#####5    | 16/29 [00:07<00:05,  2.60it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  59%|#####8    | 17/29 [00:07<00:04,  2.64it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  62%|######2   | 18/29 [00:08<00:04,  2.47it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  66%|######5   | 19/29 [00:08<00:04,  2.43it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  69%|######8   | 20/29 [00:08<00:03,  2.45it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  72%|#######2  | 21/29 [00:09<00:03,  2.49it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  76%|#######5  | 22/29 [00:09<00:02,  2.53it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  79%|#######9  | 23/29 [00:10<00:02,  2.54it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  83%|########2 | 24/29 [00:10<00:02,  2.45it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  86%|########6 | 25/29 [00:10<00:01,  2.44it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  90%|########9 | 26/29 [00:11<00:01,  2.61it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  93%|#########3| 27/29 [00:11<00:00,  2.78it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  97%|#########6| 28/29 [00:11<00:00,  2.89it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 29/29 [00:11<00:00,  3.54it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 29/29 [00:11<00:00,  2.43it/s]

# %%
# !python test.py --task val --batch-size 16 --data data/custom.yaml --img-size 416 --weights runs/train/conda_custom_env_1007/weights/best.pt --name 'val_results'
# Out:
# Namespace(weights=['runs/train/conda_custom_env_1007/weights/best.pt'], data='data/custom.yaml', batch_size=16, img_size=416, conf_thres=0.001, iou_thres=0.65, task='val', device='', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name="'val_results'", exist_ok=False, no_trace=False, v5_metric=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#                  all         455        6354       0.939       0.923        0.94       0.883
#      BackgroundImage         455          56       0.788       0.928       0.869       0.843
#      CheckedTextView         455         142       0.866       0.887       0.894       0.807
#                 Icon         455        1088       0.921       0.906        0.96       0.828
#             EditText         455         209        0.98       0.971       0.993       0.949
#                Image         455         858        0.88       0.865       0.921       0.872
#                 Text         455        2952       0.962       0.952       0.963       0.869
#           TextButton         455         427       0.962       0.972        0.99       0.982
#               Drawer         455          30       0.979           1       0.996       0.996
#        PageIndicator         455         157           1       0.965       0.987       0.828
#         UpperTaskBar         455         387       0.996       0.635       0.717        0.68
#                Modal         455          31       0.958           1       0.995       0.986
#               Switch         455          17       0.981           1       0.995       0.961
# Speed: 6.8/1.7/8.5 ms inference/NMS/total per 416x416 image at batch-size 16
# Results saved to runs\test\'val_results'
# YOLOR  2023-3-22 torch 1.11.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8191.5MB)
#
# C:\Users\Shayan\.conda\envs\Yolov7_u\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36541106 parameters, 6194944 gradients, 103.3 GFLOPS
#
# val: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\val.cache' images and labels... 455 found, 0 missing, 0 empty, 0 corrupted: 100%|##########| 455/455 [00:00<?, ?it/s]
# val: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\val.cache' images and labels... 455 found, 0 missing, 0 empty, 0 corrupted: 100%|##########| 455/455 [00:00<?, ?it/s]
#
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   0%|          | 0/29 [00:00<?, ?it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   3%|3         | 1/29 [00:01<00:41,  1.48s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   7%|6         | 2/29 [00:01<00:23,  1.13it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  10%|#         | 3/29 [00:02<00:17,  1.45it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  14%|#3        | 4/29 [00:02<00:14,  1.72it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  17%|#7        | 5/29 [00:03<00:12,  1.96it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  21%|##        | 6/29 [00:03<00:10,  2.18it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  24%|##4       | 7/29 [00:03<00:09,  2.29it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  28%|##7       | 8/29 [00:04<00:09,  2.28it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  31%|###1      | 9/29 [00:04<00:08,  2.41it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  34%|###4      | 10/29 [00:05<00:07,  2.41it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  38%|###7      | 11/29 [00:05<00:07,  2.38it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  41%|####1     | 12/29 [00:05<00:06,  2.47it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  45%|####4     | 13/29 [00:06<00:06,  2.53it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  48%|####8     | 14/29 [00:06<00:05,  2.64it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  52%|#####1    | 15/29 [00:07<00:05,  2.62it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  55%|#####5    | 16/29 [00:07<00:05,  2.55it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  59%|#####8    | 17/29 [00:07<00:04,  2.54it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  62%|######2   | 18/29 [00:08<00:04,  2.41it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  66%|######5   | 19/29 [00:08<00:04,  2.32it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  69%|######8   | 20/29 [00:09<00:04,  2.09it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  72%|#######2  | 21/29 [00:09<00:03,  2.05it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  76%|#######5  | 22/29 [00:10<00:03,  2.09it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  79%|#######9  | 23/29 [00:10<00:02,  2.07it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  83%|########2 | 24/29 [00:11<00:02,  2.08it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  86%|########6 | 25/29 [00:11<00:01,  2.04it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  90%|########9 | 26/29 [00:12<00:01,  2.08it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  93%|#########3| 27/29 [00:12<00:00,  2.27it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  97%|#########6| 28/29 [00:13<00:00,  2.46it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 29/29 [00:13<00:00,  3.01it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 29/29 [00:13<00:00,  2.20it/s]

# %%
# !python test.py --task test --batch-size 16 --data data/custom.yaml --img-size 416 --weights runs/train/conda_custom_env_1007/weights/last.pt --name 'test_results_lastpt'
# Out:
# Namespace(weights=['runs/train/conda_custom_env_1007/weights/last.pt'], data='data/custom.yaml', batch_size=16, img_size=416, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name="'test_results_lastpt'", exist_ok=False, no_trace=False, v5_metric=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#                  all         455        6190       0.933       0.899       0.934       0.872
#      BackgroundImage         455          62       0.822       0.903       0.922       0.898
#      CheckedTextView         455          71        0.86        0.69        0.74       0.651
#                 Icon         455        1111       0.937       0.919       0.964       0.829
#             EditText         455         219       0.969       0.959       0.988       0.938
#                Image         455         763       0.883       0.865       0.942       0.885
#                 Text         455        2892       0.965       0.955       0.967       0.876
#           TextButton         455         459       0.967       0.965       0.982       0.974
#               Drawer         455          19       0.975           1       0.996       0.996
#        PageIndicator         455         154       0.993       0.966       0.993       0.792
#         UpperTaskBar         455         370       0.996        0.62       0.731        0.68
#                Modal         455          31       0.936       0.942       0.984       0.976
#               Switch         455          39       0.897           1       0.996       0.967
# Speed: 6.2/1.6/7.8 ms inference/NMS/total per 416x416 image at batch-size 16
# Results saved to runs\test\'test_results_lastpt'
# YOLOR  2023-3-22 torch 1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8191.5MB)
#
# C:\Users\Shayan\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3191.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36541106 parameters, 6194944 gradients, 103.3 GFLOPS
#
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test.cache' images and labels... 455 found, 0 missing, 0 empty, 0 corrupted: 100%|##########| 455/455 [00:00<?, ?it/s]
# test: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\test.cache' images and labels... 455 found, 0 missing, 0 empty, 0 corrupted: 100%|##########| 455/455 [00:00<?, ?it/s]
#
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   0%|          | 0/29 [00:00<?, ?it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   3%|3         | 1/29 [00:01<00:37,  1.34s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   7%|6         | 2/29 [00:01<00:21,  1.24it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  10%|#         | 3/29 [00:02<00:16,  1.55it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  14%|#3        | 4/29 [00:02<00:13,  1.83it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  17%|#7        | 5/29 [00:02<00:11,  2.09it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  21%|##        | 6/29 [00:03<00:09,  2.35it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  24%|##4       | 7/29 [00:03<00:09,  2.44it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  28%|##7       | 8/29 [00:04<00:08,  2.43it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  31%|###1      | 9/29 [00:04<00:07,  2.51it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  34%|###4      | 10/29 [00:04<00:07,  2.55it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  38%|###7      | 11/29 [00:05<00:06,  2.60it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  41%|####1     | 12/29 [00:05<00:06,  2.65it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  45%|####4     | 13/29 [00:05<00:05,  2.78it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  48%|####8     | 14/29 [00:06<00:05,  2.69it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  52%|#####1    | 15/29 [00:06<00:05,  2.59it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  55%|#####5    | 16/29 [00:07<00:05,  2.58it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  59%|#####8    | 17/29 [00:07<00:04,  2.57it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  62%|######2   | 18/29 [00:07<00:04,  2.41it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  66%|######5   | 19/29 [00:08<00:04,  2.40it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  69%|######8   | 20/29 [00:08<00:03,  2.40it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  72%|#######2  | 21/29 [00:09<00:03,  2.49it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  76%|#######5  | 22/29 [00:09<00:02,  2.52it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  79%|#######9  | 23/29 [00:09<00:02,  2.48it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  83%|########2 | 24/29 [00:10<00:02,  2.41it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  86%|########6 | 25/29 [00:10<00:01,  2.39it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  90%|########9 | 26/29 [00:11<00:01,  2.54it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  93%|#########3| 27/29 [00:11<00:00,  2.68it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  97%|#########6| 28/29 [00:11<00:00,  2.78it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 29/29 [00:12<00:00,  3.20it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 29/29 [00:12<00:00,  2.41it/s]

# %%
# !python test.py --task val --batch-size 16 --data data/custom.yaml --img-size 416 --weights runs/train/conda_custom_env_1007/weights/best.pt --name 'val_results_lastpt'
# Out:
# Namespace(weights=['runs/train/conda_custom_env_1007/weights/best.pt'], data='data/custom.yaml', batch_size=16, img_size=416, conf_thres=0.001, iou_thres=0.65, task='val', device='', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name="'val_results_lastpt'", exist_ok=False, no_trace=False, v5_metric=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#                  all         455        6354        0.94       0.923        0.94       0.883
#      BackgroundImage         455          56       0.788       0.928       0.869       0.843
#      CheckedTextView         455         142       0.867       0.887       0.894       0.808
#                 Icon         455        1088       0.921       0.905        0.96       0.827
#             EditText         455         209        0.98       0.971       0.993       0.949
#                Image         455         858        0.88       0.865       0.921       0.872
#                 Text         455        2952       0.962       0.952       0.964       0.869
#           TextButton         455         427       0.962       0.972        0.99       0.982
#               Drawer         455          30       0.979           1       0.996       0.996
#        PageIndicator         455         157           1       0.965       0.986       0.825
#         UpperTaskBar         455         387       0.996       0.635       0.718        0.68
#                Modal         455          31       0.958           1       0.995       0.986
#               Switch         455          17       0.981           1       0.995       0.961
# Speed: 6.2/1.6/7.8 ms inference/NMS/total per 416x416 image at batch-size 16
# Results saved to runs\test\'val_results_lastpt'
# YOLOR  2023-3-22 torch 1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8191.5MB)
#
# C:\Users\Shayan\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3191.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36541106 parameters, 6194944 gradients, 103.3 GFLOPS
#
# val: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\val.cache' images and labels... 455 found, 0 missing, 0 empty, 0 corrupted: 100%|##########| 455/455 [00:00<?, ?it/s]
# val: Scanning 'E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\val.cache' images and labels... 455 found, 0 missing, 0 empty, 0 corrupted: 100%|##########| 455/455 [00:00<?, ?it/s]
#
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   0%|          | 0/29 [00:00<?, ?it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   3%|3         | 1/29 [00:01<00:40,  1.44s/it]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:   7%|6         | 2/29 [00:01<00:23,  1.13it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  10%|#         | 3/29 [00:02<00:17,  1.48it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  14%|#3        | 4/29 [00:02<00:14,  1.75it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  17%|#7        | 5/29 [00:03<00:11,  2.01it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  21%|##        | 6/29 [00:03<00:10,  2.23it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  24%|##4       | 7/29 [00:03<00:09,  2.35it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  28%|##7       | 8/29 [00:04<00:08,  2.34it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  31%|###1      | 9/29 [00:04<00:08,  2.45it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  34%|###4      | 10/29 [00:05<00:07,  2.52it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  38%|###7      | 11/29 [00:05<00:06,  2.61it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  41%|####1     | 12/29 [00:05<00:06,  2.65it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  45%|####4     | 13/29 [00:06<00:06,  2.64it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  48%|####8     | 14/29 [00:06<00:05,  2.78it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  52%|#####1    | 15/29 [00:06<00:05,  2.71it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  55%|#####5    | 16/29 [00:07<00:05,  2.58it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  59%|#####8    | 17/29 [00:07<00:04,  2.66it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  62%|######2   | 18/29 [00:08<00:04,  2.52it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  66%|######5   | 19/29 [00:08<00:04,  2.49it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  69%|######8   | 20/29 [00:08<00:03,  2.38it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  72%|#######2  | 21/29 [00:09<00:03,  2.40it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  76%|#######5  | 22/29 [00:09<00:02,  2.42it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  79%|#######9  | 23/29 [00:10<00:02,  2.47it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  83%|########2 | 24/29 [00:10<00:02,  2.49it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  86%|########6 | 25/29 [00:10<00:01,  2.45it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  90%|########9 | 26/29 [00:11<00:01,  2.41it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  93%|#########3| 27/29 [00:11<00:00,  2.53it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95:  97%|#########6| 28/29 [00:12<00:00,  2.62it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 29/29 [00:12<00:00,  3.08it/s]
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|##########| 29/29 [00:12<00:00,  2.36it/s]

# %%
# !python detect.py --weights runs/train/conda_custom_env_1007/weights/last.pt --conf 0.25 --img-size 416 --source test_images/ --name predict3
# Out:
# Namespace(weights=['runs/train/conda_custom_env_1007/weights/last.pt'], source='test_images/', img_size=416, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='predict3', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 2 Icons, 7 Images, 17 Texts, 1 UpperTaskBar, 1 Modal, Done. (13.4ms) Inference, (5.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\10246.jpg
# 6 Icons, 8 Images, 14 Texts, 1 Drawer, 1 UpperTaskBar, 1 Modal, Done. (14.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\10583.jpg
# 3 Icons, 10 Texts, 1 UpperTaskBar, Done. (15.9ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\10597.jpg
# 1 BackgroundImage, 1 Icon, 3 Images, 4 Texts, 1 TextButton, 1 UpperTaskBar, Done. (16.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\10624.jpg
# 3 Icons, 4 Images, 7 Texts, 1 UpperTaskBar, 1 Modal, Done. (13.7ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\10662.jpg
# 4 Icons, 2 EditTexts, 1 Image, 6 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (14.1ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\1067.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (16.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\10723.jpg
# 1 BackgroundImage, 1 EditText, 1 Image, 3 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (16.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\10763.jpg
# 4 Icons, 2 Images, 14 Texts, 1 UpperTaskBar, Done. (13.5ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\1142.jpg
# 2 Icons, 1 Image, 9 Texts, 4 TextButtons, 1 UpperTaskBar, Done. (18.5ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\11501.jpg
# 1 Icon, 1 EditText, 9 Images, 12 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (14.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\12714.jpg
# 4 Icons, 1 EditText, 3 Images, 18 Texts, 1 TextButton, 1 UpperTaskBar, Done. (14.4ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\1282.jpg
# 1 BackgroundImage, 4 Images, 8 Texts, 2 TextButtons, 1 PageIndicator, Done. (14.3ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\12825.jpg
# 10 Icons, 5 Images, 12 Texts, 1 Drawer, 1 UpperTaskBar, Done. (14.2ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\12867.jpg
# 1 BackgroundImage, 1 Image, 3 Texts, 1 TextButton, 1 UpperTaskBar, Done. (13.8ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\13202.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (16.2ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\13271.jpg
# 14 Icons, 2 Images, 13 Texts, 1 UpperTaskBar, 3 Switchs, Done. (13.2ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\13764.jpg
# 9 Icons, 8 Images, 27 Texts, 1 UpperTaskBar, Done. (15.6ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\13765.jpg
# 1 Image, 1 Text, 1 UpperTaskBar, Done. (20.6ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\13810.jpg
# 1 Image, 2 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (14.6ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\14150.jpg
# 3 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (13.8ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\14152.jpg
# 1 CheckedTextView, 1 EditText, 6 Texts, 1 TextButton, 1 UpperTaskBar, 1 Modal, Done. (14.8ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\14379.jpg
# 1 Icon, 3 Images, 6 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (16.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\14466.jpg
# 1 Image, 3 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (13.7ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\14674.jpg
# 1 Image, 2 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (12.6ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\14900.jpg
# 1 BackgroundImage, 1 Image, 3 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (16.3ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\14989.jpg
# 1 BackgroundImage, 1 Icon, 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (18.2ms) Inference, (2.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\15086.jpg
# 1 BackgroundImage, 3 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (16.5ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\15299.jpg
# 1 Icon, 15 Texts, 1 TextButton, 1 UpperTaskBar, 1 Switch, Done. (17.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\16967.jpg
# 2 Icons, 4 Images, 9 Texts, 1 TextButton, 1 UpperTaskBar, Done. (16.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\16972.jpg
# 1 Icon, 8 Texts, 1 UpperTaskBar, 1 Modal, Done. (14.2ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\17220.jpg
# 1 Image, 3 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (20.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\17568.jpg
# 1 Icon, 2 Images, 3 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (13.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\17902.jpg
# 1 BackgroundImage, 2 Images, 2 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (14.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\18298.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (13.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\18326.jpg
# 1 Image, 2 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (16.3ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\18532.jpg
# 1 BackgroundImage, 1 Text, 2 TextButtons, 1 PageIndicator, Done. (16.6ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\18556.jpg
# 2 CheckedTextViews, 11 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (16.8ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\1869.jpg
# 10 Icons, 5 Images, 12 Texts, 1 UpperTaskBar, 1 Modal, Done. (14.1ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\18783.jpg
# 1 Image, 4 Texts, 1 TextButton, 1 PageIndicator, Done. (13.3ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\18907.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (13.7ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\18970.jpg
# 8 Icons, 3 Images, 13 Texts, 1 TextButton, 1 Drawer, 1 UpperTaskBar, Done. (13.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\19886.jpg
# 1 BackgroundImage, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (14.5ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\2002.jpg
# 16 CheckedTextViews, 20 Texts, 1 UpperTaskBar, 1 Modal, Done. (17.5ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\20197.jpg
# 1 BackgroundImage, 1 EditText, 5 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (19.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\20432.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (17.5ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\20677.jpg
# 1 BackgroundImage, 3 Images, 3 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (18.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\2101.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (17.7ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\21225.jpg
# 4 Icons, 2 EditTexts, 1 Image, 6 Texts, 1 TextButton, Done. (18.3ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\21838.jpg
# 5 Icons, 2 Images, 11 Texts, 1 Drawer, 1 UpperTaskBar, Done. (18.7ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\21982.jpg
# 6 Icons, 3 Images, 6 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (18.2ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\2209.jpg
# 6 Icons, 2 Images, 9 Texts, 1 Drawer, 1 UpperTaskBar, Done. (18.1ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\22370.jpg
# 3 Icons, 1 Image, 3 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (18.7ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\22586.jpg
# 1 Image, 2 Texts, 1 PageIndicator, 1 UpperTaskBar, 1 Modal, Done. (18.8ms) Inference, (1.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\23351.jpg
# 1 Image, 2 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (19.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\23576.jpg
# 1 Image, 4 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (18.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\23579.jpg
# 4 Icons, 5 Images, 7 Texts, 1 UpperTaskBar, Done. (18.7ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\23614.jpg
# 1 BackgroundImage, 1 Icon, 1 Image, 4 Texts, 2 TextButtons, Done. (18.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\23865.jpg
# 1 BackgroundImage, 1 Image, 1 Text, 2 TextButtons, 1 UpperTaskBar, Done. (19.6ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\23936.jpg
# 1 BackgroundImage, 2 Icons, 2 EditTexts, 1 Image, 4 Texts, 1 TextButton, Done. (18.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\24155.jpg
# 1 Image, 1 Text, 4 TextButtons, 1 UpperTaskBar, Done. (18.8ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\2433.jpg
# 2 Images, 2 Texts, 3 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (18.9ms) Inference, (1.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\24683.jpg
# 2 Icons, 1 Image, 2 Texts, 1 PageIndicator, Done. (18.7ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\24894.jpg
# 10 Icons, 1 Image, 8 Texts, 1 Drawer, 1 UpperTaskBar, Done. (19.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\2500.jpg
# 5 CheckedTextViews, 1 Icon, 16 Texts, 1 UpperTaskBar, Done. (19.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\25302.jpg
# 1 BackgroundImage, 1 Image, 1 Text, 1 TextButton, 1 PageIndicator, Done. (20.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\25370.jpg
# 9 Icons, 3 Images, 10 Texts, 2 TextButtons, 1 Drawer, 1 UpperTaskBar, Done. (20.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\25731.jpg
# 1 BackgroundImage, 2 Images, 3 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (19.6ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\2694.jpg
# 1 BackgroundImage, 2 Texts, 4 TextButtons, 1 UpperTaskBar, 1 Modal, Done. (19.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\27925.jpg
# 2 Icons, 7 Texts, 1 TextButton, 1 UpperTaskBar, Done. (20.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\27956.jpg
# 2 Texts, 2 TextButtons, 1 UpperTaskBar, 1 Modal, Done. (19.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\27965.jpg
# 1 BackgroundImage, 1 Icon, 2 Images, 2 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (20.0ms) Inference, (2.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\27976.jpg
# 1 BackgroundImage, 1 Image, 2 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (20.2ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\28395.jpg
# 1 Icon, 1 Image, 3 Texts, 1 PageIndicator, Done. (20.4ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\28478.jpg
# 1 Image, 4 Texts, 1 PageIndicator, Done. (20.4ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\28482.jpg
# 2 Icons, 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (20.1ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\28526.jpg
# 9 Icons, 3 Images, 11 Texts, 1 Drawer, 1 UpperTaskBar, Done. (20.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\28531.jpg
# 1 Image, 4 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (20.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\28649.jpg
# 1 BackgroundImage, 1 Image, 2 TextButtons, 1 UpperTaskBar, Done. (20.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\2871.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 UpperTaskBar, 1 Modal, Done. (20.3ms) Inference, (2.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\28881.jpg
# 6 Icons, 4 EditTexts, 5 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (20.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\28896.jpg
# 1 BackgroundImage, 4 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (20.1ms) Inference, (2.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\29154.jpg
# 1 Image, 1 Text, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (20.4ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\29508.jpg
# 6 Icons, 1 Image, 7 Texts, 1 TextButton, 1 UpperTaskBar, Done. (20.8ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\29812.jpg
# 1 BackgroundImage, 1 Image, 3 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (20.5ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\30019.jpg
# 3 Icons, 6 Images, 10 Texts, 1 Drawer, 1 UpperTaskBar, 1 Modal, Done. (21.3ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\30147.jpg
# 1 Image, 2 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (20.1ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\30197.jpg
# 1 Icon, 1 Image, 2 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (20.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\30199.jpg
# 2 Icons, 2 EditTexts, 1 Image, 8 Texts, 1 TextButton, 1 UpperTaskBar, 1 Modal, Done. (19.9ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\30370.jpg
# 2 Icons, 2 Images, 10 Texts, 1 TextButton, 1 UpperTaskBar, 1 Modal, Done. (20.4ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\305.jpg
# 2 Icons, 1 Image, 5 Texts, 1 TextButton, 1 UpperTaskBar, 1 Modal, Done. (19.7ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\30652.jpg
# 1 BackgroundImage, 1 EditText, 1 Image, 1 Text, 2 TextButtons, 1 UpperTaskBar, Done. (19.7ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\30672.jpg
# 1 Icon, 2 Images, 10 Texts, 1 UpperTaskBar, 1 Modal, Done. (20.3ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\30821.jpg
# 7 Icons, 6 Images, 13 Texts, 1 Drawer, 1 UpperTaskBar, Done. (20.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\32024.jpg
# 1 Icon, 1 Image, 8 Texts, 1 UpperTaskBar, 1 Modal, Done. (20.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\32029.jpg
# 2 Icons, 1 Image, 5 Texts, 1 TextButton, 1 UpperTaskBar, Done. (20.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\3206.jpg
# 1 Icon, 1 Image, 2 Texts, 1 PageIndicator, Done. (20.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\323.jpg
# 5 Icons, 3 Images, 4 Texts, 1 TextButton, 1 UpperTaskBar, Done. (20.3ms) Inference, (2.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\32473.jpg
# 1 CheckedTextView, 3 Icons, 7 Texts, 1 UpperTaskBar, Done. (20.4ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\325.jpg
# 1 Icon, 3 Images, 6 Texts, 1 UpperTaskBar, 1 Modal, Done. (23.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\32611.jpg
# 2 Images, 3 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (20.0ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\33036.jpg
# 1 Image, 4 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (20.8ms) Inference, (1.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\33304.jpg
# 6 CheckedTextViews, 2 Icons, 1 Image, 14 Texts, 2 TextButtons, 1 UpperTaskBar, 1 Modal, 5 Switchs, Done. (19.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\3353.jpg
# 3 Icons, 3 Images, 7 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (20.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\33579.jpg
# 13 Icons, 1 Image, 14 Texts, 1 UpperTaskBar, 1 Switch, Done. (19.0ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\34140.jpg
# 1 Image, 6 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (20.0ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\34270.jpg
# 1 Image, 3 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (20.0ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\34386.jpg
# 1 BackgroundImage, 2 Images, 3 Texts, 3 TextButtons, Done. (21.9ms) Inference, (2.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\34735.jpg
# 1 BackgroundImage, 2 Images, 5 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (20.4ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\34870.jpg
# 4 CheckedTextViews, 1 Icon, 15 Texts, 1 UpperTaskBar, Done. (20.1ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\35372.jpg
# 1 BackgroundImage, 1 Image, 2 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (20.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\36420.jpg
# 1 Image, 2 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (23.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\36563.jpg
# 1 Icon, 2 Texts, 1 TextButton, 1 UpperTaskBar, 1 Modal, Done. (22.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\36783.jpg
# 8 Icons, 3 Images, 10 Texts, 1 UpperTaskBar, 1 Switch, Done. (22.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\370.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.3ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\3720.jpg
# 4 Icons, 2 Images, 10 Texts, 1 Drawer, 1 UpperTaskBar, Done. (22.6ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\37243.jpg
# 1 CheckedTextView, 4 EditTexts, 1 Image, 11 Texts, 1 UpperTaskBar, 1 Modal, Done. (22.4ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\37884.jpg
# 1 Image, 1 Text, 1 PageIndicator, 1 UpperTaskBar, Done. (23.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\38191.jpg
# 8 Icons, 3 Images, 12 Texts, 1 Drawer, 1 UpperTaskBar, Done. (22.6ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\38444.jpg
# 2 Icons, 1 EditText, 2 Images, 8 Texts, 3 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (22.4ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\38936.jpg
# 1 Icon, 1 Image, 3 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (22.3ms) Inference, (2.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\39304.jpg
# 2 EditTexts, 1 Image, 5 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\39322.jpg
# 4 Icons, 10 Images, 11 Texts, 1 UpperTaskBar, 1 Modal, Done. (22.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\397.jpg
# 2 EditTexts, 4 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.2ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\40540.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (22.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\40572.jpg
# 10 Icons, 9 Images, 15 Texts, 1 UpperTaskBar, Done. (22.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\41042.jpg
# 1 BackgroundImage, 1 Image, 1 Text, 2 TextButtons, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\41128.jpg
# 1 Icon, 2 EditTexts, 3 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (22.1ms) Inference, (2.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\41129.jpg
# 8 Icons, 2 Images, 8 Texts, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\41566.jpg
# 6 Icons, 1 Image, 7 Texts, 1 Drawer, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\41675.jpg
# 1 BackgroundImage, 1 Image, 2 Texts, Done. (22.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\42729.jpg
# 1 BackgroundImage, 1 Image, 3 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (22.8ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\42938.jpg
# 9 Icons, 5 Images, 11 Texts, 1 Drawer, 1 UpperTaskBar, Done. (23.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\43701.jpg
# 2 CheckedTextViews, 1 EditText, 2 Images, 10 Texts, 1 UpperTaskBar, 1 Modal, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\44525.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (22.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\44565.jpg
# 2 Images, 1 Text, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (22.9ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\45005.jpg
# 1 Icon, 2 EditTexts, 5 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (21.5ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\45861.jpg
# 1 Image, 1 Text, 1 TextButton, 1 UpperTaskBar, Done. (21.8ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\46082.jpg
# 1 Icon, 2 EditTexts, 4 Texts, 1 UpperTaskBar, Done. (21.9ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\475.jpg
# 9 Icons, 13 Texts, 1 Drawer, 1 UpperTaskBar, Done. (22.1ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\4755.jpg
# 1 BackgroundImage, 1 Image, 3 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (22.3ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\47766.jpg
# 1 Image, 1 Text, 1 PageIndicator, 1 UpperTaskBar, Done. (22.5ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\48381.jpg
# 2 Icons, 5 Images, 5 Texts, 1 UpperTaskBar, Done. (22.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\48572.jpg
# 1 Image, 5 Texts, 1 TextButton, 1 Modal, Done. (21.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\4912.jpg
# 6 Icons, 1 Image, 12 Texts, 1 Drawer, 1 UpperTaskBar, Done. (21.4ms) Inference, (2.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\49686.jpg
# 1 Icon, 2 EditTexts, 1 Image, 4 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (21.7ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\49815.jpg
# 1 Image, 4 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (22.3ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\51274.jpg
# 1 BackgroundImage, 1 Image, 2 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (21.6ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\52415.jpg
# 3 Icons, 2 EditTexts, 4 Texts, 1 TextButton, 1 UpperTaskBar, Done. (21.9ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\52991.jpg
# 1 BackgroundImage, 2 EditTexts, 1 Image, 7 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (22.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\53184.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (22.2ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\53550.jpg
# 1 Icon, 5 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (21.9ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\53882.jpg
# 1 Image, 3 Texts, 3 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (22.2ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\54019.jpg
# 1 Image, 3 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (21.8ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\54589.jpg
# 1 BackgroundImage, 2 Images, 4 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (21.0ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\55314.jpg
# 1 BackgroundImage, 1 Image, 2 Texts, 1 TextButton, 1 UpperTaskBar, Done. (21.5ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\55558.jpg
# 2 Icons, 4 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (21.9ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\55589.jpg
# 2 Icons, 4 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (21.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\55593.jpg
# 1 BackgroundImage, 2 EditTexts, 3 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (22.5ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\557.jpg
# 3 Texts, 3 TextButtons, 1 UpperTaskBar, 1 Modal, Done. (22.2ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\5578.jpg
# 1 Image, 2 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (23.0ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\56220.jpg
# 5 Icons, 3 Images, 8 Texts, 1 TextButton, 1 Drawer, 1 UpperTaskBar, Done. (23.0ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\56786.jpg
# 1 BackgroundImage, 2 Images, 4 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (23.2ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\57039.jpg
# 1 Image, 3 Texts, 1 UpperTaskBar, Done. (23.8ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\57563.jpg
# 7 Icons, 5 Images, 8 Texts, 1 TextButton, 1 Drawer, 1 UpperTaskBar, Done. (23.7ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\57907.jpg
# 1 Image, 1 Text, 1 TextButton, 1 PageIndicator, Done. (34.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\58658.jpg
# 1 Image, 4 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (36.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\58706.jpg
# 2 Icons, 3 EditTexts, 5 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (35.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\59100.jpg
# 2 Icons, 4 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (35.6ms) Inference, (2.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\59562.jpg
# 5 Images, 4 Texts, 1 UpperTaskBar, 1 Modal, Done. (34.5ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\6024.jpg
# 1 Icon, 1 Image, 4 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (35.0ms) Inference, (2.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\60246.jpg
# 1 Icon, 2 EditTexts, 5 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (35.4ms) Inference, (2.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\60326.jpg
# 2 Images, 4 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (35.5ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\6140.jpg
# 3 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (35.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\6143.jpg
# 5 Icons, 2 Images, 6 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (22.0ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\61471.jpg
# 2 CheckedTextViews, 2 Images, 4 Texts, 1 Modal, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\61631.jpg
# 2 CheckedTextViews, 3 Icons, 3 Images, 14 Texts, 1 TextButton, 1 Modal, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\6208.jpg
# 5 Icons, 5 Texts, 1 UpperTaskBar, Done. (22.2ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\62370.jpg
# 2 Icons, 1 Image, 1 Text, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (22.0ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\62469.jpg
# 1 Icon, 3 Images, 9 Texts, 1 UpperTaskBar, Done. (22.3ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\63102.jpg
# 5 Icons, 5 Images, 11 Texts, 1 UpperTaskBar, Done. (21.6ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\63773.jpg
# 5 Icons, 9 Images, 9 Texts, 1 Drawer, 1 UpperTaskBar, Done. (21.3ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\63997.jpg
# 8 Icons, 3 Images, 9 Texts, 1 Drawer, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\64034.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (21.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\64934.jpg
# 1 Image, 4 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (21.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\64997.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (21.0ms) Inference, (3.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\65546.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, Done. (21.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\66999.jpg
# 2 Images, 2 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (21.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\6864.jpg
# 4 Icons, 2 Images, 8 Texts, 1 Drawer, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\69578.jpg
# 3 Images, 1 Text, 1 PageIndicator, 1 UpperTaskBar, Done. (21.5ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\7000.jpg
# 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (21.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\7060.jpg
# 1 Image, 3 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (21.3ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\70622.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (21.5ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\7737.jpg
# 8 Icons, 3 Images, 10 Texts, 1 Drawer, 1 UpperTaskBar, Done. (22.2ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\7931.jpg
# 1 BackgroundImage, 2 Images, 3 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.1ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\8535.jpg
# 3 Icons, 10 Texts, 1 UpperTaskBar, 3 Switchs, Done. (21.7ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\9222.jpg
# 1 Image, 2 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (22.3ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\9382.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (19.7ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\9617.jpg
# 1 Icon, 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, 1 Modal, Done. (19.9ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\9635.jpg
# 1 BackgroundImage, 1 Image, 5 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (20.8ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\9921.jpg
# 5 Icons, 11 Images, 15 Texts, 1 UpperTaskBar, 1 Modal, Done. (20.2ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_1.jpg
# 7 Icons, 6 EditTexts, 8 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (21.4ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_133.jpg
# 2 Icons, 2 EditTexts, 6 Texts, 4 TextButtons, 1 UpperTaskBar, Done. (20.7ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_142.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (20.9ms) Inference, (3.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_160.jpg
# 2 Icons, 1 Image, 4 Texts, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_168.jpg
# 3 Texts, 1 TextButton, 1 PageIndicator, Done. (21.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_173.jpg
# 1 BackgroundImage, 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (20.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_190.jpg
# 5 Icons, 2 EditTexts, 1 Image, 9 Texts, 1 TextButton, 1 UpperTaskBar, 1 Modal, Done. (24.5ms) Inference, (4.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_20.jpg
# 1 Icon, 1 Image, 2 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (25.0ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_209.jpg
# 1 BackgroundImage, 1 Icon, 3 Texts, 3 TextButtons, 2 PageIndicators, 1 UpperTaskBar, Done. (21.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_222.jpg
# 1 Icon, 1 EditText, 3 Texts, 1 TextButton, 1 UpperTaskBar, Done. (21.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_224.jpg
# 6 Icons, 1 EditText, 9 Images, 15 Texts, 1 UpperTaskBar, Done. (23.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_228.jpg
# 2 Images, 4 Texts, 2 TextButtons, 1 PageIndicator, 1 UpperTaskBar, Done. (21.0ms) Inference, (2.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_242.jpg
# 4 Icons, 1 EditText, 1 Image, 9 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (21.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_243.jpg
# 1 BackgroundImage, 2 Icons, 2 EditTexts, 3 Images, 6 Texts, 1 TextButton, 1 UpperTaskBar, Done. (23.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_249.jpg
# 2 Icons, 2 EditTexts, 4 Texts, Done. (27.2ms) Inference, (2.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_255.jpg
# 1 BackgroundImage, 1 Image, 3 Texts, 1 TextButton, 1 UpperTaskBar, Done. (20.1ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_269.jpg
# 3 Images, 4 Texts, 4 TextButtons, 1 UpperTaskBar, Done. (21.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_308.jpg
# 1 CheckedTextView, 2 Icons, 1 EditText, 1 Image, 6 Texts, 1 TextButton, 1 UpperTaskBar, Done. (20.2ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_316.jpg
# 7 Icons, 2 EditTexts, 2 Images, 14 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (19.8ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_322.jpg
# 1 EditText, 3 Texts, 1 TextButton, 1 UpperTaskBar, Done. (20.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_326.jpg
# 16 Icons, 14 Texts, 1 TextButton, Done. (19.5ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_34.jpg
# 2 Icons, 1 Image, 4 Texts, 1 PageIndicator, Done. (20.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_382.jpg
# 4 Icons, 8 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (20.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_387.jpg
# 1 BackgroundImage, 1 Icon, 3 Texts, 1 PageIndicator, 1 UpperTaskBar, Done. (21.5ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_388.jpg
# 5 Icons, 4 Images, 7 Texts, Done. (21.2ms) Inference, (2.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_4.jpg
# 1 Icon, 2 EditTexts, 1 Image, 6 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (21.0ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_402.jpg
# 1 Icon, 7 Images, 4 Texts, 1 TextButton, 1 UpperTaskBar, Done. (21.6ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_405.jpg
# 6 Icons, 1 Image, 11 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_407.jpg
# 1 Icon, 3 EditTexts, 13 Texts, 1 TextButton, 1 UpperTaskBar, 3 Switchs, Done. (21.5ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_410.jpg
# 6 Icons, 6 Images, 11 Texts, 1 UpperTaskBar, Done. (21.0ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_416.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (20.9ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_421.jpg
# 4 Icons, 2 Images, 7 Texts, 1 TextButton, Done. (20.8ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_425.jpg
# 2 Icons, 1 Image, 3 Texts, 1 PageIndicator, Done. (21.6ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_442.jpg
# 1 BackgroundImage, 1 Icon, 1 Image, 2 Texts, 4 TextButtons, Done. (21.5ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_446.jpg
# 3 Icons, 4 Images, 11 Texts, 1 TextButton, Done. (21.9ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_450.jpg
# 1 Icon, 1 EditText, 3 Texts, 1 TextButton, 1 UpperTaskBar, Done. (21.8ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_453.jpg
# 1 Icon, 7 Images, 4 Texts, 1 TextButton, 1 UpperTaskBar, Done. (21.5ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_475.jpg
# 6 Icons, 4 Images, 11 Texts, 4 TextButtons, 1 UpperTaskBar, Done. (21.9ms) Inference, (2.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_490.jpg
# 5 Icons, 6 Images, 6 Texts, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_505.jpg
# 1 BackgroundImage, 1 Icon, 1 Image, 3 Texts, 2 TextButtons, 1 UpperTaskBar, Done. (21.6ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_507.jpg
# 5 Icons, 6 Images, 13 Texts, 1 UpperTaskBar, Done. (21.9ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_509.jpg
# 8 Icons, 3 Images, 9 Texts, 1 UpperTaskBar, Done. (21.3ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_515.jpg
# 1 Icon, 2 Texts, 21 TextButtons, Done. (21.3ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_52.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (21.1ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_521.jpg
# 2 Icons, 2 Images, 10 Texts, Done. (21.8ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_529.jpg
# 6 Icons, 9 Images, 13 Texts, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_53.jpg
# 1 Icon, 3 Images, 4 Texts, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_561.jpg
# 8 Icons, 4 Images, 12 Texts, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_562.jpg
# 4 Icons, 5 Images, 11 Texts, Done. (23.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_565.jpg
# 2 Icons, 2 EditTexts, 6 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_578.jpg
# 3 Icons, 9 EditTexts, 12 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_59.jpg
# 5 Icons, 1 Image, 7 Texts, Done. (21.5ms) Inference, (2.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_590.jpg
# 1 Icon, 7 Images, 4 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_594.jpg
# 6 Icons, 1 Image, 7 Texts, Done. (22.4ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_609.jpg
# 5 Icons, 5 Images, 8 Texts, Done. (22.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_615.jpg
# 5 Icons, 1 Image, 8 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_617.jpg
# 7 Icons, 4 Images, 7 Texts, 1 TextButton, 1 UpperTaskBar, Done. (21.6ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_619.jpg
# 10 Icons, 1 EditText, 5 Images, 20 Texts, 1 UpperTaskBar, Done. (22.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_622.jpg
# 5 Icons, 2 Images, 11 Texts, 5 TextButtons, 1 UpperTaskBar, Done. (22.3ms) Inference, (2.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_623.jpg
# 1 Icon, 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, 1 UpperTaskBar, Done. (22.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_628.jpg
# 9 Icons, 1 EditText, 6 Images, 17 Texts, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_630.jpg
# 1 Icon, 1 EditText, 3 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.3ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_632.jpg
# 5 Icons, 12 Texts, Done. (22.6ms) Inference, (2.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_634.jpg
# 1 BackgroundImage, 1 Image, 4 Texts, 2 TextButtons, Done. (21.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_651.jpg
# 1 Icon, 2 EditTexts, 7 Texts, 2 TextButtons, Done. (22.2ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_661.jpg
# 5 Icons, 4 Images, 8 Texts, 1 UpperTaskBar, Done. (21.5ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_698.jpg
# 8 Icons, 4 Images, 10 Texts, 4 TextButtons, 1 UpperTaskBar, Done. (21.9ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_699.jpg
# 1 CheckedTextView, 11 Icons, 4 Images, 13 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_700.jpg
# 1 Icon, 2 Images, 4 Texts, 2 TextButtons, 1 PageIndicator, Done. (21.4ms) Inference, (2.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_739.jpg
# 5 Icons, 2 EditTexts, 1 Image, 14 Texts, 3 TextButtons, 1 UpperTaskBar, Done. (21.5ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_74.jpg
# 2 Icons, 3 EditTexts, 3 Texts, 1 TextButton, 1 UpperTaskBar, Done. (22.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_77.jpg
# 3 CheckedTextViews, 1 Icon, 8 Texts, 1 TextButton, Done. (22.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Android_96.jpg
# 1 Icon, 1 Image, 3 Texts, Done. (21.6ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_1335.jpg
# 1 CheckedTextView, 2 Icons, 2 EditTexts, 11 Texts, 2 TextButtons, 1 Switch, Done. (21.5ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_1536.jpg
# 1 BackgroundImage, 1 Image, 3 Texts, 1 TextButton, Done. (22.4ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_1552.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (22.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_1563.jpg
# 1 Icon, 8 Images, 10 Texts, Done. (23.8ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_1611.jpg
# 7 Icons, 1 Image, 13 Texts, Done. (22.5ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_1634.jpg
# 1 BackgroundImage, 1 Icon, 1 Image, 4 Texts, 1 TextButton, Done. (23.0ms) Inference, (2.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_1834.jpg
# 1 Icon, 6 Images, 1 Text, 1 Modal, Done. (22.4ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_2272.jpg
# 5 Icons, 14 Texts, 1 Switch, Done. (22.6ms) Inference, (2.0ms) NMS
# ...
# 5 Icons, 4 Images, 6 Texts, Done. (20.5ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_8756.jpg
# 6 BackgroundImages, 6 CheckedTextViews, 8 Texts, 1 TextButton, Done. (18.6ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_8769.jpg
# 1 Image, 3 Texts, 2 TextButtons, 1 PageIndicator, Done. (21.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_8777.jpg
# 1 Image, 3 Texts, 2 TextButtons, 1 PageIndicator, Done. (20.0ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_8780.jpg
# 1 Image, 4 Texts, 1 TextButton, 1 PageIndicator, Done. (19.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_8809.jpg
# 4 Icons, 5 EditTexts, 1 Image, 9 Texts, 1 TextButton, Done. (22.9ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_898262.jpg
# 1 Icon, 2 EditTexts, 6 Texts, 1 TextButton, Done. (21.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_899288.jpg
# 1 Icon, 1 Image, 3 Texts, Done. (20.2ms) Inference, (2.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_899597.jpg
# 1 CheckedTextView, 1 Icon, 6 EditTexts, 1 Image, 7 Texts, 1 TextButton, Done. (20.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_901450.jpg
# 1 Icon, 9 Images, 14 Texts, Done. (26.1ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_902631.jpg
# 1 Icon, 2 Images, 2 Texts, 2 TextButtons, 1 PageIndicator, Done. (21.3ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_903677.jpg
# 15 Icons, 8 Images, 9 Texts, Done. (20.9ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_904456.jpg
# 5 Icons, 3 Images, 12 Texts, 1 TextButton, Done. (20.8ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_905481.jpg
# 2 Images, 2 Texts, 1 TextButton, 1 PageIndicator, Done. (16.9ms) Inference, (2.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_9060.jpg
# 8 Icons, 1 EditText, 3 Images, 11 Texts, Done. (20.5ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_906161.jpg
# 3 Icons, 3 Images, 10 Texts, 3 TextButtons, 1 PageIndicator, Done. (20.8ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_909464.jpg
# 5 Icons, 2 Images, 11 Texts, 2 TextButtons, Done. (20.8ms) Inference, (1.7ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_909750.jpg
# 13 Icons, 5 Images, 17 Texts, Done. (20.5ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_91037.jpg
# 14 Icons, 1 EditText, 4 Images, 13 Texts, 4 TextButtons, Done. (21.0ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_910569.jpg
# 8 Icons, 12 Texts, 1 Switch, Done. (23.5ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_910637.jpg
# 1 BackgroundImage, 2 Icons, 2 EditTexts, 2 Images, 5 Texts, 1 TextButton, Done. (24.1ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_910999.jpg
# 1 Image, 5 Texts, 1 TextButton, Done. (24.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_911069.jpg
# 1 Icon, 4 EditTexts, 10 Texts, 2 TextButtons, Done. (35.9ms) Inference, (2.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_911531.jpg
# 1 Image, 3 Texts, 1 PageIndicator, Done. (34.9ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_912047.jpg
# 9 Icons, 3 Images, 10 Texts, 1 TextButton, Done. (35.1ms) Inference, (2.4ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_912785.jpg
# 1 Image, 4 Texts, 1 TextButton, 1 PageIndicator, Done. (35.7ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_913735.jpg
# 6 Icons, 1 EditText, 7 Images, 14 Texts, Done. (35.3ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_914161.jpg
# 2 Images, 5 Texts, 1 TextButton, 1 PageIndicator, Done. (36.3ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_9160.jpg
# 1 Icon, 1 Image, 4 Texts, 1 TextButton, Done. (35.9ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_9358.jpg
# 2 Icons, 2 EditTexts, 2 Images, 8 Texts, 3 TextButtons, Done. (36.8ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\IMG_9946.jpg
# 3 Icons, 1 EditText, 1 Image, 3 Texts, 1 TextButton, Done. (36.8ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Login1_IKnowYou.jpg
# 1 BackgroundImage, 2 Icons, 2 EditTexts, 2 Images, 5 Texts, 1 TextButton, Done. (38.0ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Login_Holiday.jpg
# 2 Icons, 2 EditTexts, 3 Images, 3 Texts, 1 TextButton, Done. (36.9ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\Login_OZZON.jpg
# 1 Image, 4 Texts, 1 PageIndicator, Done. (30.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_101.jpg
# 1 Image, 2 Texts, 1 PageIndicator, Done. (29.6ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_12.jpg
# 3 Icons, 2 EditTexts, 4 Texts, 1 TextButton, Done. (18.9ms) Inference, (3.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_139.jpg
# 1 Icon, 1 Image, 4 Texts, 1 PageIndicator, Done. (23.6ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_14.jpg
# 1 Icon, 1 Image, 3 Texts, 1 PageIndicator, Done. (18.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_143.jpg
# 2 Icons, 1 Image, 3 Texts, 1 PageIndicator, Done. (22.4ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_151.jpg
# 1 Image, 3 Texts, Done. (16.3ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_16.jpg
# 1 BackgroundImage, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (17.4ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_169.jpg
# 1 Image, 3 Texts, 1 PageIndicator, Done. (19.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_179.jpg
# 1 Image, 1 Text, 2 TextButtons, Done. (15.7ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_193.jpg
# 1 Image, 4 Texts, 1 PageIndicator, Done. (18.6ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_194.jpg
# 2 Icons, 1 Image, 4 Texts, 1 PageIndicator, Done. (23.1ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_197.jpg
# 1 Icon, 2 Images, 4 Texts, 1 PageIndicator, Done. (17.0ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_211.jpg
# 2 Icons, 1 Image, 1 Text, 1 PageIndicator, Done. (18.3ms) Inference, (1.9ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_213.jpg
# 4 Icons, 2 EditTexts, 5 Texts, 1 TextButton, Done. (18.1ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_23.jpg
# 1 Image, 4 Texts, 1 PageIndicator, Done. (18.3ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_230.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, Done. (18.7ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_234.jpg
# 1 Icon, 1 Image, 4 Texts, 1 PageIndicator, Done. (17.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_238.jpg
# 1 Image, 2 Texts, 1 TextButton, Done. (16.0ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_239.jpg
# 2 EditTexts, 1 Image, 1 Text, 2 TextButtons, Done. (21.9ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_246.jpg
# 5 Icons, 2 EditTexts, 1 Image, 6 Texts, 1 TextButton, Done. (19.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_251.jpg
# 1 BackgroundImage, 2 Icons, 2 EditTexts, 1 Image, 9 Texts, 1 TextButton, Done. (20.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_273.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (17.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_276.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (18.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_28.jpg
# 1 BackgroundImage, 2 Texts, 1 TextButton, Done. (16.6ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_291.jpg
# 1 Image, 3 Texts, 1 PageIndicator, Done. (18.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_299.jpg
# 2 Icons, 1 Image, 3 Texts, 1 PageIndicator, Done. (21.2ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_308.jpg
# 1 Image, 4 Texts, 1 TextButton, Done. (16.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_311.jpg
# 1 Image, 2 Texts, 1 PageIndicator, Done. (20.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_32.jpg
# 2 Icons, 1 Image, 1 Text, 1 PageIndicator, Done. (16.7ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_324.jpg
# 1 Icon, 1 Image, 5 Texts, 1 PageIndicator, Done. (16.5ms) Inference, (1.8ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_329.jpg
# 1 Icon, 1 Image, 2 Texts, 1 PageIndicator, Done. (19.9ms) Inference, (1.3ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_335.jpg
# 1 BackgroundImage, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (20.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_338.jpg
# 1 Image, 4 Texts, 1 PageIndicator, Done. (17.7ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_376.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, Done. (17.0ms) Inference, (2.1ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_38.jpg
# 1 Image, 2 Texts, 1 TextButton, 1 PageIndicator, Done. (19.1ms) Inference, (2.2ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_395.jpg
# 1 Icon, 4 Texts, 2 TextButtons, Done. (19.6ms) Inference, (2.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_403.jpg
# 1 BackgroundImage, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (19.6ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_414.jpg
# 4 Icons, 1 Image, 3 Texts, 1 PageIndicator, Done. (15.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_441.jpg
# 1 Icon, 2 EditTexts, 1 Image, 6 Texts, 3 TextButtons, Done. (21.0ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_45.jpg
# 1 BackgroundImage, 1 Icon, 2 EditTexts, 1 Image, 4 Texts, 2 TextButtons, Done. (20.4ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_507.jpg
# 1 BackgroundImage, 2 EditTexts, 4 Texts, 2 TextButtons, Done. (14.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_521.jpg
# 4 Icons, 2 EditTexts, 6 Texts, 1 TextButton, Done. (21.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_544.jpg
# 1 BackgroundImage, 3 Icons, 2 EditTexts, 7 Texts, 2 TextButtons, Done. (18.4ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_548.jpg
# 1 BackgroundImage, 2 EditTexts, 1 Image, 5 Texts, 2 TextButtons, Done. (18.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_558.jpg
# 4 Icons, 3 EditTexts, 1 Image, 7 Texts, 1 TextButton, Done. (15.0ms) Inference, (1.5ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_575.jpg
# 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (34.7ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_586.jpg
# 1 CheckedTextView, 3 Icons, 5 EditTexts, 8 Texts, 1 TextButton, Done. (17.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_615.jpg
# 1 CheckedTextView, 2 Icons, 5 EditTexts, 7 Texts, 1 TextButton, Done. (22.0ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_644.jpg
# 1 BackgroundImage, 1 EditText, 1 Image, 6 Texts, 2 TextButtons, Done. (22.5ms) Inference, (5.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_645.jpg
# 3 Icons, 3 EditTexts, 1 Image, 5 Texts, 1 TextButton, Done. (17.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_647.jpg
# 1 Image, 2 Texts, 1 TextButton, Done. (16.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_68.jpg
# 1 Icon, 3 EditTexts, 6 Texts, 1 TextButton, Done. (12.1ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_689.jpg
# 1 BackgroundImage, 2 EditTexts, 7 Texts, 2 TextButtons, Done. (13.3ms) Inference, (1.6ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_721.jpg
# 1 Image, 3 Texts, 1 PageIndicator, Done. (17.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_727.jpg
# 2 EditTexts, 7 Texts, 3 TextButtons, Done. (16.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_737.jpg
# 3 EditTexts, 5 Texts, 1 TextButton, Done. (18.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_743.jpg
# 1 BackgroundImage, 2 EditTexts, 1 Image, 4 Texts, 1 TextButton, Done. (17.0ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_780.jpg
# 1 Icon, 1 Image, 3 Texts, 1 TextButton, 1 PageIndicator, Done. (22.1ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_81.jpg
# 1 BackgroundImage, 1 Icon, 2 EditTexts, 1 Image, 4 Texts, 1 TextButton, Done. (20.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_811.jpg
# 2 Icons, 2 EditTexts, 6 Texts, 1 TextButton, Done. (15.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_826.jpg
# 2 EditTexts, 1 Image, 3 Texts, 3 TextButtons, Done. (14.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_838.jpg
# 1 Image, 1 Text, 1 TextButton, 1 PageIndicator, Done. (16.0ms) Inference, (2.0ms) NMS
#  The image with the result is saved in: runs\detect\predict3\uplabs_94.jpg
# Done. (43.025s)
# YOLOR  2023-3-22 torch 1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8191.5MB)
#
# C:\Users\Shayan\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ..\aten\src\ATen\native\TensorShape.cpp:3191.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36541106 parameters, 6194944 gradients, 103.3 GFLOPS
