# %%
import sys
sys.path.insert(1, 'E:/Research/course research projects/data-driven software engineering/gui-element-detection/src')

# %%
# !pip install ultralytics
# !pip install -r requirements.txt -> removed for git, available on ultralytics GitHub repository
# %cd yolov8
# Out:
# E:\Research\course research projects\data-driven software engineering\gui-element-detection\src\yolo\yolov8

# %%
DATASET_YML = r'"E:/Research/course research projects/data-driven software engineering/gui-element-detection/src/yolo/yolov8/ds.yaml"'
def train(epochs = 100, image_size=416):
    # !yolo detect train data={DATASET_YML} model=yolov8s.yaml pretrained=True epochs={epochs} imgsz={image_size} verbose=True


def test():
    # !yolo detect predict model=r'"E:/Research/course research projects/data-driven software engineering/gui-element-detection/src/yolo/yolov8/runs/detect/train4/weights/best.pt"' source=r'"E:/Research/course research projects/data-driven software engineering/datasets/All Dataset/Merged/dataset/images/test/"' save=True

# %%
# train(epochs=300)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
# ...

# %%
test()
# Out:
# Ultralytics YOLOv8.0.55  Python-3.10.9 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# YOLOv8s summary (fused): 168 layers, 11130228 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/455 E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\images\test\10246.jpg: 416x256 2 Icons, 5 Images, 11 Texts, 1 UpperTaskBar, 1 Modal, 16.0ms
# image 2/455 E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\images\test\10583.jpg: 416x256 4 Icons, 8 Images, 13 Texts, 1 UpperTaskBar, 1 Modal, 9.0ms
# image 3/455 E:\Research\course research projects\data-driven software engineering\datasets\All Dataset\Merged\dataset\images\test\10597.jpg: 416x256 3 Icons, 10 Texts, 2 UpperTaskBars, 9.0ms
# ...
